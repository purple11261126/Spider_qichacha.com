# %%
import Ipynb_importer

# %%
import url_manage, web_download, web_parsing
import requests  # http://blog.csdn.net/gyq1998/article/details/78583841
from xml import etree

# %%
url = 'http://www.qichacha.com/search?key={name}#p:{num}&'
url = url.format(name='小米', num='2')
print(url)

headers = {
    'Connection' : 'keep-alive',
    'Cookie' : 'zg_did=%7B%22did%22%3A%20%22161656e666717f-05e041ab0f746e8-4c322172-1fa400-161656e666878f%22%7D; zg_de1d1a35bfa24ce29bbf2c7eb17e6c4f=%7B%22sid%22%3A%201518079785363%2C%22updated%22%3A%201518079847203%2C%22info%22%3A%201517825189486%2C%22superProperty%22%3A%20%22%7B%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22localhost%3A8888%22%2C%22cuid%22%3A%20%226c19524a673ac045babafcedac2b6453%22%7D; _uab_collina=151782519867722924826534; UM_distinctid=161656ffdee4ff-052af228aec4738-4c322172-1fa400-161656ffdef769; CNZZDATA1254842228=1930218608-1517821373-%7C1517821373; _umdata=486B7B12C6AA95F25F430F3BD1C599F0B8963DA670190565365CACB94D015DE2A931945AA222E77FCD43AD3E795C914C016A68544FB1EDAB47A8332C57BAF16F; acw_tc=AQAAABabtxmL5A4AMxIdPHGnakvlsg6k; PHPSESSID=t3k1p8vb6btch0apml7or9phq7; hasShow=1',
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:58.0) Gecko/20100101 Firefox/58.0',
}
# Out:
# http://www.qichacha.com/search?key=小米#p:2&

# %%
r = requests.get(url, timeout=10, headers=headers)
print(r.text)
# Out:
#  <!DOCTYPE html> <html lang="en"> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,Chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no"> <meta name="renderer" content="webkit"> <meta name="author" content="leslie"> <title>小米的搜索结果_企查查</title> <meta name="keywords" content="企查查,企业查询,公司查询,工商查询,企业信用信息查询系统,企业工商信息查询,企业财务信息查询,企业失信信息查询,启信宝,天眼查"> <meta name="description" content="企查查为您提供企业信息查询,工商查询,信用查询,公司查询等相关信息查询；帮您快速了解企业信息,企业工商信息,企业信用信息,企业失信信息等企业经营和人员投资状况,查询更多企业信息就到企查查官网！"> <link rel="icon" href="/material/theme/chacha/cms/v2/images/favicon.png"> <link rel="stylesheet" href="/material/theme/chacha/cms/v2/css/bootstrap.css" type="text/css" /> <link rel="stylesheet" href="/material/theme/chacha/cms/v2/css/font-awesome.min.css" type="text/css" /> <link rel="stylesheet" href="/material/theme/chacha/cms/v2/css/icon.css" type="text/css" /> <link rel="stylesheet" href="/material/theme/chacha/cms/v2/css/font.css" type="text/css" /> <link rel="stylesheet" href="/material/theme/chacha/cms/v2/css/app.css?time=201802023" type="text/css" /> <!--[if lt IE 9]>
#     <link rel="stylesheet" href="/material/theme/chacha/cms/v2/css/app_ie8.css?time=1508428800" type="text/css" />
#     <script src="https://mos.meituan.com/media/lib/html5shiv.js"></script>
#     <script src="https://mos.meituan.com/media/lib/respond.js"></script>
#     <![endif]--> <script type="text/javascript" src="/material/js/siteconfig.js"></script> <script src="/material/theme/chacha/cms/v2/js/jquery.min.js"></script> <script type="text/javascript" src="/material/theme/chacha/cms/v2/js/jquery.scrollTo.js"></script> <script src="/material/theme/chacha/cms/v2/js/bootstrap.js"></script> <script type="text/javascript" src="/material/js/echarts.min.js"></script> <script type="text/javascript" src="/material/theme/chacha/cms/v2/js/china.js?time=1508428800"></script> <link rel="stylesheet" href="/material/theme/chacha/cms/v2/css/toastr.css" /> <script type="text/javascript" src="/material/theme/chacha/cms/v2/js/chartsUtil.js?times=1508428800"></script> <script src="/material/theme/chacha/cms/v2/js/toastr.js" type="text/javascript"></script> <script src="/material/theme/chacha/cms/v2/js/custom.js?time=20180202"></script> <script type="text/javascript">
#     //window.onerror=function(e){console.error(e);return true;}
#     window.zhuge = window.zhuge || [];window.zhuge.methods = "_init debug identify track trackLink trackForm page".split(" ");
#     window.zhuge.factory = function(b) {return function() {var a = Array.prototype.slice.call(arguments);a.unshift(b);
#         window.zhuge.push(a);return window.zhuge;}};for (var i = 0; i < window.zhuge.methods.length; i++) {
#         var key = window.zhuge.methods[i];window.zhuge[key] = window.zhuge.factory(key);}window.zhuge.load = function(b, x) {
#         if (!document.getElementById("zhuge-js")) {var a = document.createElement("script");var verDate = new Date();
#             var verStr = verDate.getFullYear().toString()+ verDate.getMonth().toString() + verDate.getDate().toString();
#             a.type = "text/javascript";a.id = "zhuge-js";a.async = !0;a.src = (location.protocol == 'http:' ? "http://tongji.qichacha.com/zhuge.js" : 'https://tongji.qichacha.com/zhuge.js');
#             a.onerror = function(){window.zhuge.identify = window.zhuge.track = function(ename, props, callback){if(callback && Object.prototype.toString.call(callback) === '[object Function]')callback();};};
#             var c = document.getElementsByTagName("script")[0];c.parentNode.insertBefore(a, c);window.zhuge._init(b, x)}};
#     window.zhuge.load('de1d1a35bfa24ce29bbf2c7eb17e6c4f',{
#         visualizer: true,
#         autoTrack:false
#     });
#             var zhugeIdentify = {
#             name:  '企鹅ourslj',
#             groupid:  '11',
#             client_type:'0',
#             mobile:'13512834525',
#             email:'',
#             regist_time:'2018-02-06 10:56:48'
#         };
#         var vipStartTime = '0';
#         if(vipStartTime){
#             zhugeIdentify.vip_start_time = '';
#         }
#         window.zhuge.identify('6c19524a673ac045babafcedac2b6453', zhugeIdentify);
#                 window.zhuge.track('搜索列表',{
#             '关键词':'小米'
#         });
#     </script> </head> <body> <header class="header navi-header box-shadow"> <div class="container "> <div class="navi-brand"> <a href="/" > <img src="/material/theme/chacha/cms/v2/images/logo4.png" class="m-r-sm" alt="企查查"> </a> </div> <form class="navi-form" role="search" action="/search"> <div class="form-group"> <div class="input-group"> <input id="headerKey" name="key" onkeydown="searchKeydown(event,2);" class="form-control headerKey" style="font-size: 14px;" type="text" placeholder="请输入企业名称、人名，产品名等，多关键词用空格隔开，如“小米 雷军”" value="小米" autocomplete="off"> <span class="input-group-btn" style="float: left"> <button type="submit" class="btn btn-primary top-searchbtn"></button> </span> </div> </div> <section class="panel headerKey header-section" id="header-search-list"></section> </form> <script type="text/javascript">
#                 var pathname_ = window.location.pathname;
#                 if(pathname_ == '/search_riskinfo' || pathname_ == '/search_intellectualinfo'){
#                     $('#tpsearch').attr('action', pathname_);
#                 }
#             </script> <ul class="navi-nav pull-right"> <li class="" class="dropdown"> <a href="/app" class="dropdown-toggle header-qrcode">
#                     APP下载
#                   </a> <section class="dropdown-menu qrcode-box"> <img src="/material/theme/chacha/cms/v2/images/header_qrcode@2x.png"> </section> </li> <li  class="head-line">|</li> <li class=""><a href="/vip" target="_blank">会员服务</a></li> <li  class="head-line">|</li> <li class=""><a href="/vip_qiye" target="_blank">企业版</a></li> <li  class="head-line">|</li> <li class="dropdown"> <a href="#" class="dropdown-toggle" data-toggle="dropdown"> <span class="headface"> <img src=" /material/theme/chacha/cms/v2/images/icon_user2_default@2x.png" alt="个人中心"> </span>
#                                       企鹅ours…
#
#
#                     <b class="caret"></b> </a> <ul class="dropdown-menu nav-user"> <li> <a href="/msg">
#                                                          消息中心
#                         </a> </li> <li> <a href="/radar"> 我的监控</a> </li> <li class="divider"></li> <li> <a href="/balance_manage"> 我的账户</a> </li> <li> <a href="/user_credit"> 用户积分</a> </li> <li class="divider"></li> <li> <a href="/order_manage"> 我的报告</a> </li> <li> <a  href="/user_follow"> 我的关注</a> </li> <li><a href="/user_download"> 我的下载</a></li> <li><a href="/user_note"> 我的笔记</a></li> <li> <a href="/user_setting"> 账号设置</a> </li> <li class="divider"></li> <li> <a href="/user_logout"> 退出</a> </li> </ul> </li> </ul> </div> </header> <script type="text/javascript" src="/material/js/jquery.cookie.js"></script> <script type="text/javascript" src="/material/js/jquery.validate.min.js"></script> <script type="text/javascript" src="/material/js/jquery.form.min.js"></script> <script type="text/javascript" src="/material/js/global.js"></script> <style>
#     #excelTipsModal .modal-dialog,#filtrationModal .modal-dialog{
#         width: 400px;
#         margin: 30px auto;
#     }
#     #excelTipsModalBody{
#         width: 100%;
#         height: 60px;
#     }
#
#
# </style> <div id="V3_SL" class="container m-t-md"> <div class="row"> <div class="col-md-9 no-padding"> <div class="col-md-12 search-sidebar hidden-xs no-padding-right" id="smartBox"> <div class="v3_sl_tab"> <a href="/search?key=小米" class="active">公司</a> <a href="/search_riskinfo?key=小米" class="">风险信息</a> <a href="/search_intellectualinfo?key=小米" class="">知识产权</a> </div> <section class="panel b-a" id="search-options"> <div id="SearchBox"> <div class="panel panel-default" id="appendBox" style="padding:15px 0;display: none;border:none;border-bottom: 1px dashed #ccc;box-shadow:none;margin-bottom:5px; "> <span class="font-15 text-dark m-l" id="has_condition"></span> <span class="m-l label btn-primary indexChoosen appendSpan clearSpan" data-option="index" style="padding:5px;cursor:pointer;"></span> <span class="m-l label btn-primary searchTypeChoosen appendSpan clearSpan" data-option="searchType" style="padding:5px;cursor:pointer;"></span> <span class="m-l label btn-primary statusCodeChoosen appendSpan clearSpan" data-option="statusCode" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary registfundChoosen appendSpan clearSpan" data-option="registfund" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary startDateChoosen appendSpan clearSpan" data-option="startDate" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary provinceChoosen appendSpan clearSpan" data-option="province" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary cityChoosen appendSpan clearSpan" data-option="city" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary countyChoosen appendSpan clearSpan" data-option="county" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary industrycodeChoosen appendSpan clearSpan" data-option="industrycode" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary subindustrycodeChoosen appendSpan clearSpan" data-option="subindustrycode" style="padding:5px;cursor:pointer"></span> <span class="m-l label btn-primary thirdindustrycodeChoosen appendSpan clearSpan" data-option="thirdindustrycode" style="padding:5px;cursor:pointer"></span> <a href="/search?key=小米" class="m-l clearSpan pull-right" data-option="All" style="padding:5px;cursor:pointer;padding-right:20px;">全部清除</a> </div> <dl class="sfilter-tag clearfix indexChoose" id="indexOld"> <div class="pull-left" style="width:76px;"><dt>查找范围</dt></div> <div class="pull-left" style="width:80%;"> <dd> <a href="javascript:;" data-option="index" data-value="2" data-append="企业名">
#                                         企业名
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="index" data-value="4" data-append="法人或股东">
#                                         法人或股东
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="index" data-value="6" data-append="高管">
#                                         高管
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="index" data-value="8" data-append="品牌/产品">
#                                         品牌/产品
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="index" data-value="10" data-append="联系方式">
#                                         联系方式
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="index" data-value="12" data-append="经营范围">
#                                         经营范围
#                                     </a> </dd> </div> </dl> <dl class="sfilter-tag clearfix searchTypeChoose" id="indexOld"> <div class="pull-left" style="width:76px;"><dt>机构类型</dt></div> <div class="pull-left" style="width:80%;"> <dd> <a href="javascript:;" data-option="searchType" data-value="0" data-append="企业">
#                                         企业
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="searchType" data-value="1" data-append="社会组织">
#                                         社会组织
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="searchType" data-value="3" data-append="香港公司">
#                                         香港公司
#                                     </a> </dd> <dd> <a href="javascript:;" data-option="searchType" data-value="5" data-append="台湾公司">
#                                         台湾公司
#                                     </a> </dd> </div> </dl> <dl class="sfilter-tag clearfix statusCodeChoose" id="statuscodeOld"> <div class="pull-left" style="width:76px;"><dt>企业状态</dt></div> <div class="pull-left" style="width:85%;"> <dd><a href="javascript:;" data-option="statusCode" data-value="0" data-append="暂无">暂无(361)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="10" data-append="正常">正常(5545)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="100" data-append="废止">废止(5)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="117" data-append="核准设立">核准设立(18)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="127" data-append="解散">解散(13)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="20" data-append="存续">存续(30856)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="60" data-append="迁出">迁出(12)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="80" data-append="撤销">撤销(1)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="90" data-append="吊销">吊销(1456)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="92" data-append="仍注册">仍注册(32)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="94" data-append="已告解散">已告解散(7)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="99" data-append="注销">注销(8712)</a></dd> <dd><a href="javascript:;" data-option="statusCode" data-value="999" data-append="正常">正常(93)</a></dd> </div> </dl> <dl class="sfilter-tag clearfix registfundChoose" id="registcapiOld"> <div class="pull-left" style="width:76px;"><dt>注册资本</dt></div> <div class="pull-left" style="width:80%;"> <dd> <a href="javascript:;" data-option="registfund" data-value="0-499" data-append="500万以下">500万以下</a> </dd> <dd> <a href="javascript:;" data-option="registfund" data-value="500-1000" data-append="500~1000万">500~1000万</a> </dd> <dd> <a href="javascript:;" data-option="registfund" data-value="1000-5000" data-append="1000~5000万">1000~5000万</a> </dd> <dd> <a href="javascript:;" data-option="registfund" data-value="5000-0" data-append="5000万以上">5000万以上</a> </dd> </div> </dl> <dl class="sfilter-tag clearfix startDateChoose" id="startdateOld"> <div class="pull-left" style="width:76px;"><dt>成立日期</dt></div> <div class="pull-left" style="width:80%;"> <dd > <a href="javascript:;" data-option="startDate" data-value="2018" data-append="2018">
#                                         2018&nbsp;(505)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="startDate" data-value="2017" data-append="2017">
#                                         2017&nbsp;(11172)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="startDate" data-value="2016" data-append="2016">
#                                         2016&nbsp;(8445)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="startDate" data-value="2015" data-append="2015">
#                                         2015&nbsp;(6720)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="startDate" data-value="2014" data-append="2014">
#                                         2014&nbsp;(4318)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2013" data-append="2013">
#                                         2013&nbsp;(3131)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2012" data-append="2012">
#                                         2012&nbsp;(2378)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2011" data-append="2011">
#                                         2011&nbsp;(1784)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2010" data-append="2010">
#                                         2010&nbsp;(1381)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2009" data-append="2009">
#                                         2009&nbsp;(1343)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2008" data-append="2008">
#                                         2008&nbsp;(1261)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2007" data-append="2007">
#                                         2007&nbsp;(958)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2006" data-append="2006">
#                                         2006&nbsp;(540)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2005" data-append="2005">
#                                         2005&nbsp;(522)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2004" data-append="2004">
#                                         2004&nbsp;(569)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2003" data-append="2003">
#                                         2003&nbsp;(399)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2002" data-append="2002">
#                                         2002&nbsp;(221)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2001" data-append="2001">
#                                         2001&nbsp;(167)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="2000" data-append="2000">
#                                         2000&nbsp;(270)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1999" data-append="1999">
#                                         1999&nbsp;(78)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1998" data-append="1998">
#                                         1998&nbsp;(77)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1997" data-append="1997">
#                                         1997&nbsp;(54)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1996" data-append="1996">
#                                         1996&nbsp;(43)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1995" data-append="1995">
#                                         1995&nbsp;(47)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1994" data-append="1994">
#                                         1994&nbsp;(33)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1993" data-append="1993">
#                                         1993&nbsp;(50)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1992" data-append="1992">
#                                         1992&nbsp;(32)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1991" data-append="1991">
#                                         1991&nbsp;(25)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1990" data-append="1990">
#                                         1990&nbsp;(30)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1989" data-append="1989">
#                                         1989&nbsp;(36)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1988" data-append="1988">
#                                         1988&nbsp;(5)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1987" data-append="1987">
#                                         1987&nbsp;(6)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1986" data-append="1986">
#                                         1986&nbsp;(5)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1985" data-append="1985">
#                                         1985&nbsp;(5)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1984" data-append="1984">
#                                         1984&nbsp;(10)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1983" data-append="1983">
#                                         1983&nbsp;(7)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1982" data-append="1982">
#                                         1982&nbsp;(2)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1981" data-append="1981">
#                                         1981&nbsp;(4)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1980" data-append="1980">
#                                         1980&nbsp;(1)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1979" data-append="1979">
#                                         1979&nbsp;(1)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1978" data-append="1978">
#                                         1978&nbsp;(1)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1977" data-append="1977">
#                                         1977&nbsp;(1)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1974" data-append="1974">
#                                         1974&nbsp;(1)
#                                     </a> </dd> <dd class="startdate-dd" style="display:none;" > <a href="javascript:;" data-option="startDate" data-value="1967" data-append="1967">
#                                         1967&nbsp;(1)
#                                     </a> </dd> </div> <a class="btn btn-link btn-sm pull-right v3_a_more" id="show-date" style="margin-top:-3px;"><span>更多</span> <i class="i i-arrow-down4"></i></a> </dl> <dl class="sfilter-tag clearfix provinceChoose" id="provinceOld"> <div class="pull-left" style="width:76px;"><dt>省份地区</dt></div> <div class="pull-left" style="width:80%;"> <dd class="province-dd" style="display:none;" > </dd> <dd > <a href="javascript:;" data-option="province" data-value="AH" data-append="安徽" class="showCity">
#                                         安徽 ( 1378 )
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="province" data-value="BJ" data-append="北京" class="showCity">
#                                         北京 ( 272 )
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="province" data-value="CN" data-append="总局" class="showCity">
#                                         总局 ( 19 )
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="province" data-value="CQ" data-append="重庆" class="showCity">
#                                         重庆 ( 424 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="FJ" data-append="福建" class="showCity">
#                                         福建 ( 1176 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="GD" data-append="广东" class="showCity">
#                                         广东 ( 3069 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="GS" data-append="甘肃" class="showCity">
#                                         甘肃 ( 508 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="GX" data-append="广西" class="showCity">
#                                         广西 ( 1409 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="GZ" data-append="贵州" class="showCity">
#                                         贵州 ( 1354 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="HAIN" data-append="海南" class="showCity">
#                                         海南 ( 221 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="HB" data-append="河北" class="showCity">
#                                         河北 ( 2413 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="HEN" data-append="河南" class="showCity">
#                                         河南 ( 3135 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="HK" data-append="香港特别行政区" class="showCity">
#                                         香港特别行政区 ( 39 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="HLJ" data-append="黑龙江" class="showCity">
#                                         黑龙江 ( 1556 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="HUB" data-append="湖北" class="showCity">
#                                         湖北 ( 1191 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="HUN" data-append="湖南" class="showCity">
#                                         湖南 ( 1265 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="JL" data-append="吉林" class="showCity">
#                                         吉林 ( 1682 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="JS" data-append="江苏" class="showCity">
#                                         江苏 ( 2756 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="JX" data-append="江西" class="showCity">
#                                         江西 ( 957 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="LN" data-append="辽宁" class="showCity">
#                                         辽宁 ( 1337 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="NMG" data-append="内蒙古" class="showCity">
#                                         内蒙古 ( 1066 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="NX" data-append="宁夏" class="showCity">
#                                         宁夏 ( 177 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="QH" data-append="青海" class="showCity">
#                                         青海 ( 165 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="SAX" data-append="陕西" class="showCity">
#                                         陕西 ( 2237 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="SC" data-append="四川" class="showCity">
#                                         四川 ( 2839 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="SD" data-append="山东" class="showCity">
#                                         山东 ( 3547 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="SH" data-append="上海" class="showCity">
#                                         上海 ( 252 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="SX" data-append="山西" class="showCity">
#                                         山西 ( 2172 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="TJ" data-append="天津" class="showCity">
#                                         天津 ( 272 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="TW" data-append="台湾省" class="showCity">
#                                         台湾省 ( 37 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="XJ" data-append="新疆" class="showCity">
#                                         新疆 ( 2766 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="XZ" data-append="西藏" class="showCity">
#                                         西藏 ( 158 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="YN" data-append="云南" class="showCity">
#                                         云南 ( 3461 )
#                                     </a> </dd> <dd class="province-dd" style="display:none;" > <a href="javascript:;" data-option="province" data-value="ZJ" data-append="浙江" class="showCity">
#                                         浙江 ( 1763 )
#                                     </a> </dd> </div> <a class="btn btn-link btn-sm pull-right v3_a_more" id="show-province" style="margin-top:-3px;"><span>更多</span> <i class="i i-arrow-down4"></i></a> </dl> <dl class="sfilter-tag clearfix cityChoose" id="cityOld" style="display: none"> <div class="pull-left" style="width:76px;"><dt>城市</dt></div> <div class="pull-left" style="width:80%;" id="city_show"> </div> </dl> <dl class="sfilter-tag clearfix countyChoose" id="countyOld" style="display: none"> <div class="pull-left" style="width:76px;"><dt>区县</dt></div> <div class="pull-left" style="width:80%;" id="county_show"> </div> </dl> <dl class="sfilter-tag clearfix industrycodeChoose" id="industrycodeOld"> <div class="pull-left" style="width:76px;"><dt>行业门类</dt></div> <div class="pull-left" style="width:80%;"> <dd > <a href="javascript:;" data-option="industrycode" data-value="0" data-append="其他行业">
#                                         其他行业&nbsp;(20821)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="industrycode" data-value="A" data-append="农、林、牧、渔业">
#                                         农、林、牧、渔业&nbsp;(2470)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="industrycode" data-value="B" data-append="采矿业">
#                                         采矿业&nbsp;(43)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="industrycode" data-value="C" data-append="制造业">
#                                         制造业&nbsp;(2149)
#                                     </a> </dd> <dd > <a href="javascript:;" data-option="industrycode" data-value="D" data-append="电力、热力、燃气及水生产和供应业">
#                                         电力、热力、燃气及水生产和供应业&nbsp;(11)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="E" data-append="建筑业">
#                                         建筑业&nbsp;(149)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="F" data-append="批发和零售业">
#                                         批发和零售业&nbsp;(8188)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="G" data-append="交通运输、仓储和邮政业">
#                                         交通运输、仓储和邮政业&nbsp;(105)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="H" data-append="住宿和餐饮业">
#                                         住宿和餐饮业&nbsp;(10835)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="I" data-append="信息传输、软件和信息技术服务业">
#                                         信息传输、软件和信息技术服务业&nbsp;(292)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="J" data-append="金融业">
#                                         金融业&nbsp;(88)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="K" data-append="房地产业">
#                                         房地产业&nbsp;(64)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="L" data-append="租赁和商务服务业">
#                                         租赁和商务服务业&nbsp;(516)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="M" data-append="科学研究和技术服务业">
#                                         科学研究和技术服务业&nbsp;(375)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="N" data-append="水利、环境和公共设施管理业">
#                                         水利、环境和公共设施管理业&nbsp;(8)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="O" data-append="居民服务、修理和其他服务业">
#                                         居民服务、修理和其他服务业&nbsp;(818)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="P" data-append="教育">
#                                         教育&nbsp;(19)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="Q" data-append="卫生和社会工作">
#                                         卫生和社会工作&nbsp;(7)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="R" data-append="文化、体育和娱乐业">
#                                         文化、体育和娱乐业&nbsp;(129)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="S" data-append="公共管理、社会保障和社会组织">
#                                         公共管理、社会保障和社会组织&nbsp;(21)
#                                     </a> </dd> <dd class="industrycode-dd" style="display:none;" > <a href="javascript:;" data-option="industrycode" data-value="T" data-append="国际组织">
#                                         国际组织&nbsp;(3)
#                                     </a> </dd> </div> <a class="btn btn-link btn-sm pull-right v3_a_more" id="show-industrycode" style="margin-top:-3px;"><span>更多</span> <i class="i i-arrow-down4"></i></a> </dl> <dl class="sfilter-tag clearfix subindustrycodeChoose" id="subindustrycodeOld" style="display: none"> <div class="pull-left" style="width:76px;"><dt>行业大类</dt></div> <div class="pull-left" style="width:80%;" id="subindustrycode_show"> </div> </dl> <dl class="sfilter-tag clearfix thirdindustrycodeChoose" id="thirdindustrycodeOld" style="display: none"> <div class="pull-left" style="width:76px;"><dt>行业</dt></div> <div class="pull-left" style="width:80%;" id="thirdindustrycode_show"> </div> </dl> <div class="sfilter-tag clearfix"> <div class="pull-left" style="width:76px;"><dt>高级筛选</dt></div> <div class="pull-left" style="width:80%;"> <dd><a data-toggle="modal" data-target="#filtrationModal">有联系电话</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">无联系电话</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">有联系邮箱</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">无联系邮箱</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">有商标</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">无商标</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">有专利</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">无专利</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">有融资信息</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">无融资信息</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">已上市</a></dd> <dd><a data-toggle="modal" data-target="#filtrationModal">未上市</a></dd> </div> </div> </div> </section> <div class="hideSearchBoxWrap"> <a class="" id="hideSearchBox"><span>收起</span> <i class="i i-arrow-up4"></i></a> </div> </div> <div class="col-md-12 no-padding" id="load_data" style="display: none"> <section class="text-center" style="padding:100px 0;"> <img src="/material/theme/chacha/cms/v2/images/preloader.gif" style="width:70px;margin-top:50px;"/> </section> </div> <div class="col-md-12 no-padding-right" id="ajaxlist"> <div class="panel panel-default" style="padding:15px 0 45px;margin-bottom: -1px;"> <span class="font-15 text-dark pull-left m-l" id="countOld">
# 						                                小查为您找到
#                                 <span class="text-danger">
#                                      5000+                                 </span>
#                             家符合条件的企业
#
#                        </span> <div class="btn-group m-r m_export" style="float: right"> <a href="/vip_index" target="_blank"> <span class="btn btn-primary ma_bt" >
#                                 导出数据
#                             </span> </a> <a data-toggle="modal" data-target="#excelTipsModal" style="cursor: pointer;">
#                             &nbsp;&nbsp;
#                             <i class="i i-question"></i> </a> </div> <div class="btn-group m-r" style="float: right"> <span class="font-15 text-dark pull-left m-l btn btn-default dropdown-toggle" data-toggle="dropdown" style="padding: 2px 10px"> <span class="sortDesc">默认排序</span> <span class="caret m-l"></span> </span> <ul class="dropdown-menu text-left  pull-none-xs animated fadeInRight startdateBox" id="data_sort"> <li><a href="javascript:;" class="sortChoose" data-option="sortField" data-value="0-0">默认排序</a></li> <li><a href="javascript:;" class="sortChoose" data-option="sortField" data-value="startdate-true">成立日期升序</a></li> <li><a href="javascript:;" class="sortChoose" data-option="sortField" data-value="startdate-false">成立日期降序</a></li> <li><a href="javascript:;" class="sortChoose" data-option="sortField" data-value="registcapi-true">注册资本升序</a></li> <li><a href="javascript:;" class="sortChoose" data-option="sortField" data-value="registcapi-false">注册资本降序</a></li> </ul> </div> </div> <section class="panel b-a" id="searchlist"> <table class="m_srchList"> <thead> <tr id="search-tab-title"> <th width="70px">公司</th> <th></th> <th width="100px">状态</th> </tr> </thead> <tbody> <tr> <td> <img src="http://co-image.qichacha.com/CompanyImage/9cce0780ab7644008b73bc2120479d31.jpg" > </td> <td> <a href="/firm_9cce0780ab7644008b73bc2120479d31.html" target="_blank" target="_blank" class="ma_h1"><em><em>小米</em></em>科技有限责任公司</a><br/> <p class="m-t-xs">
#                                                                                     法定代表人：
#                                                                                 <a class="text-primary" href="/people?name=%E9%9B%B7%E5%86%9B&keyno=9cce0780ab7644008b73bc2120479d31">雷军</a> <span class="m-l">注册资本：185000万人民币</span> <span class="m-l">成立时间：2010-03-03</span> </p> <p class="m-t-xs">
#                                      电话：010-60606666-1000
#                                      <span class="m-l">邮箱：chenchongwei@xiaomi.com</span> </p> <p class="m-t-xs">
#                                      地址：北京市海淀区清河中街68号华润五彩城购物中心二期13层
#                                     </p> </p> </td> <td> <span class="nstatus text-success-lt m-l-xs">在业</span> </td> </tr> <tr> <td> <img src="http://co-image.qichacha.com/CompanyImage/default.jpg" > </td> <td> <a href="/firm_80af5085726bb6b9c7770f1e4d0580f4.html" target="_blank" target="_blank" class="ma_h1"><em><em>小米</em></em>通讯技术有限公司</a><br/> <p class="m-t-xs">
#                                                                                     法定代表人：
#                                                                                 <a class="text-primary" href="/people?name=%E9%BB%8E%E4%B8%87%E5%BC%BA&keyno=80af5085726bb6b9c7770f1e4d0580f4">黎万强</a> <span class="m-l">注册资本：13000万美元</span> <span class="m-l">成立时间：2010-08-25</span> </p> <p class="m-t-xs">
#                                      电话：010-60606666-1000
#                                      <span class="m-l">邮箱：chenchongwei@xiaomi.com</span> </p> <p class="m-t-xs">
#                                      地址：北京市海淀区清河中街68号华润五彩城购物中心二期9层
#                                     </p> </p> </td> <td> <span class="nstatus text-success-lt m-l-xs">在业</span> </td> </tr> <tr> <td> <img src="http://co-image.qichacha.com/CompanyImage/0c408616f468cf48abbd52d4b82a5ad4.jpg" > </td> <td> <a href="/firm_0c408616f468cf48abbd52d4b82a5ad4.html" target="_blank" target="_blank" class="ma_h1">北京<em><em>小米</em></em>保险经纪有限公司</a><br/> <p class="m-t-xs">
#                                                                                     法定代表人：
#                                                                                 <a class="text-primary" href="/people?name=%E6%B4%AA%E9%94%8B&keyno=0c408616f468cf48abbd52d4b82a5ad4">洪锋</a> <span class="m-l">注册资本：5000万人民币</span> <span class="m-l">成立时间：2005-04-29</span> </p> <p class="m-t-xs">
#                                      电话：010-60606666-1000
#                                      <span class="m-l">邮箱：chenchongwei@xiaomi.com</span> </p> <p class="m-t-xs">
#                                      地址：北京市海淀区清河朱房路临66号E栋1单元
#                                     </p> </p> </td> <td> <span class="nstatus text-success-lt m-l-xs">在业</span> </td> </tr> <tr> <td> <img src="http://co-image.qichacha.com/CompanyImage/default.jpg" > </td> <td> <a href="/firm_69a076b91273c94cd50c4117cca7d0f4.html" target="_blank" target="_blank" class="ma_h1">深圳华大<em><em>小米</em></em>产业股份有限公司</a><br/> <p class="m-t-xs">
#                                                                                     法定代表人：
#                                                                                 <a class="text-primary" href="/people?name=%E6%A2%85%E6%B0%B8%E7%BA%A2&keyno=69a076b91273c94cd50c4117cca7d0f4">梅永红</a> <span class="m-l">注册资本：5000万元</span> <span class="m-l">成立时间：2015-07-28</span> </p> <p class="m-t-xs">
#                                      电话：0755-36307275
#                                      <span class="m-l">邮箱：bgi-millet@genomics.cn</span> </p> <p class="m-t-xs">
#                                      地址：深圳市大鹏新区大鹏街道鹏飞路7号
#                                     </p> </p> </td> <td> <span class="nstatus text-success-lt m-l-xs">存续</span> </td> </tr> <tr> <td> <img src="http://co-image.qichacha.com/CompanyImage/22126be5733858b32a6e76133e5639ca.jpg" > </td> <td> <a href="/firm_22126be5733858b32a6e76133e5639ca.html" target="_blank" target="_blank" class="ma_h1">深圳市大米和<em><em>小米</em></em>文化传播有限公司</a><br/> <p class="m-t-xs">
#                                                                                     法定代表人：
#                                                                                 <a class="text-primary" href="/people?name=%E5%A7%9C%E8%8B%B1%E7%88%BD&keyno=22126be5733858b32a6e76133e5639ca">姜英爽</a> <span class="m-l">注册资本：106.3830万元</span> <span class="m-l">成立时间：2014-10-27</span> </p> <p class="m-t-xs">
#                                      电话：18602006753
#                                      <span class="m-l">邮箱：18602006753@qq.com</span> </p> <p class="m-t-xs">
#                                      地址：深圳市福田区梅林街道上梅林凯丰路凯丰花园二期3栋B座18B
#                                     </p> </p> </td> <td> <span class="nstatus text-success-lt m-l-xs">存续</span> </td> </tr> <tr> <td> <img src="http://co-image.qichacha.com/CompanyImage/default.jpg" > </td> <td> <a href="/firm_9eb0be8a839dc95eb8f5588fef1a855b.html" target="_blank" target="_blank" class="ma_h1"><em><em>小米</em></em>卫浴有限公司</a><br/> <p class="m-t-xs">
# ...
#                                                                 <a href="http://hlj.qichacha.com" target="_blank">黑龙江企业</a>&nbsp;|
#                                                                 <a href="http://hen.qichacha.com" target="_blank">河南企业</a>&nbsp;|
#                                                                 <a href="http://hub.qichacha.com" target="_blank">湖北企业</a>&nbsp;|
#                                                                 <a href="http://hun.qichacha.com" target="_blank">湖南企业</a>&nbsp;|
#                                                                 <a href="http://js.qichacha.com" target="_blank">江苏企业</a>&nbsp;|
#                                                                 <a href="http://jx.qichacha.com" target="_blank">江西企业</a>&nbsp;|
#                                                                 <a href="http://jl.qichacha.com" target="_blank">吉林企业</a>&nbsp;|
#                                                                 <a href="http://ln.qichacha.com" target="_blank">辽宁企业</a>&nbsp;|
#                                                                 <a href="http://nmg.qichacha.com" target="_blank">内蒙古企业</a>&nbsp;|
#                                                                 <a href="http://nx.qichacha.com" target="_blank">宁夏企业</a>&nbsp;|
#                                                                 <a href="http://qh.qichacha.com" target="_blank">青海企业</a>&nbsp;|
#                                                                 <a href="http://sd.qichacha.com" target="_blank">山东企业</a>&nbsp;|
#                                                                 <a href="http://sh.qichacha.com" target="_blank">上海企业</a>&nbsp;|
#                                                                 <a href="http://sx.qichacha.com" target="_blank">山西企业</a>&nbsp;|
#                                                                 <a href="http://sax.qichacha.com" target="_blank">陕西企业</a>&nbsp;|
#                                                                 <a href="http://sc.qichacha.com" target="_blank">四川企业</a>&nbsp;|
#                                                                 <a href="http://tj.qichacha.com" target="_blank">天津企业</a>&nbsp;|
#                                                                 <a href="http://xj.qichacha.com" target="_blank">新疆企业</a>&nbsp;|
#                                                                 <a href="http://xz.qichacha.com" target="_blank">西藏企业</a>&nbsp;|
#                                                                 <a href="http://yn.qichacha.com" target="_blank">云南企业</a>&nbsp;|
#                                                                 <a href="http://zj.qichacha.com" target="_blank">浙江企业</a>&nbsp;|
#                                                             </div> </div> <div class="row footer-bottom text-center"> <div class="text-muted m-t-sm"> <span><a href="javascript:void(0)" title="企查查">&copy;2014-2018</a> <a href="http://www.miibeian.gov.cn/" target="_blank"> 苏ICP备15042526号-4</a> 版权所有&nbsp;苏州朗动网络科技有限公司</span> </div> </div> </footer> <div class="col-sm-12 text-center"> <div class="text-muted m-t-sm"> <span>交流QQ群：467569586  369254293  257048933  259189047  371601207  374037798</span> <a href="https://ss.knet.cn/verifyseal.dll?sn=e17091132050068868mhtm000000&comefrom=trust" rel="nofollow" target="_blank"> <img class="m-l-sm" style="width: 80px" src="/material/theme/chacha/cms/v2/images/dependable.png"/> </a> <a href="http://www.jsdsgsxt.gov.cn/mbm/entweb/elec/certView.shtml?siteId=2f2c5b85a5154355a56eb3dee98ad8a3" rel="nofollow" target="_blank"> <img class="m-l-sm" style="width: 40px" src="/material/theme/chacha/cms/v2/images/jsdsgsxt.png"/> </a> </div> </div> </div> </div> </div> </footer> <div class="modal fade" id="feedModal" tabindex="-1" role="dialog" style="overflow: hidden;" aria-labelledby="myModalLabel" aria-hidden="true"> <div class="modal-dialog"> <div class="modal-content"> <div class="modal-header"> <button type="button" class="close" data-dismiss="modal"><span aria-hidden="true">&times;</span><span class="sr-only">x</span></button> <h4 class="modal-title" id="myModalLabel">意见反馈</h4> </div> <div class="modal-body"> <form class="form-horizontal" role="form"> <div class="form-group"> <label for="inputEmail3" class="col-sm-2">反馈内容</label> <div class="col-sm-10"> <textarea class="form-control content" rows="5"  name="content" placeholder="亲爱的用户：请在这里直接填写您遇到的问题或意见建议，您的意见是我们前进的动力"></textarea> <span class="contentmsg text-danger"></span> </div> </div> <div class="form-group"> <label for="inputPassword3" class="col-sm-2">联系方式</label> <div class="col-sm-10"> <input type="text" class="form-control email" name="email" placeholder="请输入邮箱，方便我们联系您。"> <span class="emailmsg text-danger"></span> </div> </div> <div class="form-group m-t-lg"> <label for="inputPassword3" class="col-sm-2"></label> <div class="col-sm-10  text-center"> <span class="btn btn-primary btn-guest btn-block">提交反馈</span> </div> </div> </form> </div> </div> </div> </div> <div style="display:none;"> <script src="https://s4.cnzz.com/z_stat.php?id=1254842228&web_id=1254842228" language="JavaScript"></script> <script>(function(){
#         var src = (document.location.protocol == "http:") ? "http://js.passport.qihucdn.com/11.0.1.js?db135ad770b0860a90c3a2ca38cf577c":"https://jspassport.ssl.qhimg.com/11.0.1.js?db135ad770b0860a90c3a2ca38cf577c";
#         document.write('<script src="' + src + '" id="sozz"><\/script>');
#     })();
#     </script> </div> <script type="text/javascript">
#     (function(){
#         var bp = document.createElement('script');
#         var curProtocol = window.location.protocol.split(':')[0];
#         if (curProtocol === 'https') {
#             bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#         }
#         else {
#             bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#         }
#         var s = document.getElementsByTagName("script")[0];
#         s.parentNode.insertBefore(bp, s);
#     })();
#
#     /*v3*/
#     jQuery(function(){
#     	jQuery("#V3_APP").mouseover(function(){
#     		$("#V3_APP_Img").show();
#     	}).mouseout(function(){
#     		$("#V3_APP_Img").hide();
#     	});
#     	jQuery("#V3_WX").mouseover(function(){
#     		$("#V3_WX_Img").show();
#     	}).mouseout(function(){
#     		$("#V3_WX_Img").hide();
#     	});
#     });
#
#     /*
#     var kicked = '';
#     if(kicked){
#         toastr.options = {positionClass: 'toast-bottom-left'};
#         toastr.error('您的账号在另一地点登录，您已被迫下线');
#     }
#     */
# </script> <link rel="stylesheet" type="text/css" href="/material/theme/chacha/cms/v2/css/rnav.css?timestamp=1497542400"> <div id="RNav" class="visible-lg i_hide"> <div class="i_menu"> <ul class="i_bts-outer" style="bottom:69px;"> <li class="i_bt_sm i_bt_wx"> <label>微信</label><img src="/material/theme/chacha/cms/v2/images/leftnav/bg_wx.png" alt="企查查"></li> <li class="i_bt_sm i_bt_dow"> <label>下载</label><img src="/material/theme/chacha/cms/v2/images/leftnav/bg_app.png" alt="企查查"></li> <li id="RNBack" class="i_bt_sm i_bt_back" data-toggle="modal" data-target="#feedModal"> <label>反馈</label></li> <li id="RNTop" class="i_bt_sm i_bt_top"> <label>置顶</label></li> </ul> </div> <div class="i_container"> <div class="i_nodata">暂无数据</div> <div id="RNFoc" class="i_wrap"> <div class="i_title">我的关注</div> <div class="i_com-wrap"> <div style="height:1px;width:240px;"></div> </div> <div class="i_botbt"> <a href="/user_follow">打开全部</a> </div> </div> <div id="RNCom" class="i_wrap"> <div class="i_title">企业对比</div> <div class="i_toast">
# 				还可以添加<span id="ComLastCount">5</span>家企业
# 				<a id="ClearCompares" class="c_a">清空</a> </div> <div class="i_com-wrap"> <div class="i_com i_addcom" data-toggle="modal" data-target="#qaddComPanel"> <img src="/material/theme/chacha/cms/v2/images/leftnav/icon-add.png" alt="企查查"/> <a class="c_a" href="javascript:;">添加企业</a> </div> <div style="height:1px;width:240px;"></div> </div> <div class="i_botbt"> <a id="RNComA" href="javascript:;" target-url="/compare">对比企业</a> </div> </div> <div id="RNRel" class="i_wrap"> <div class="i_title">找关系</div> <div class="i_toast">
# 				还可以添加<span id="RelLastCount">5</span>家企业
# 				<a class="c_a" id="ClearRels">清空</a> </div> <div class="i_com-wrap"> <div class="i_com i_addcom" data-toggle="modal" data-target="#addRelPanel"> <img src="/material/theme/chacha/cms/v2/images/leftnav/icon-add.png" alt="企查查"/> <a class="c_a" href="javascript:;">添加企业或个人</a> </div> <div style="height:1px;width:240px;"></div> </div> <div class="i_botbt"> <a href="javascript:;" target-url="/more_analysis" id="RelOpenAll">找关系</a> </div> </div> </div> <div class="modal fade" id="qaddComPanel" tabindex="-1" role="dialog" aria-labelledby="myModalLabel" aria-hidden="true"> <div class="modal-dialog"> <div class="modal-content" style="width:600px;"> <div class="modal-header"> <button type="button" class="close" data-dismiss="modal"><span aria-hidden="true">&times;</span><span class="sr-only">x</span></button> <h4 class="modal-title">添加企业</h4> </div> <div class="modal-body" style="height: 330px"> <form class="form-horizontal" role="form"> <div class="form-group"> <div class="col-sm-12 m-t-md"> <input type="text" id="qcomName" name="comName" class="form-control" value="" placeholder="请输入公司/人" autocomplete="off" oninput="qsearchCom(event,this)"/> <section class="panel hidden-xs" id="qsearchList" style="position: absolute;width: 560px;z-index: 10;display: none;"></section> </div> <div class="col-sm-12 text-center m-t-lg" style="padding-left: 18px;padding-right: 18px;"> <span id="qaddComPanelConfirm" class="btn-primary btn-guest btn-block" style="padding-top: 5px;padding-bottom: 5px;cursor:pointer;">添加企业</span> </div> </div> </form> </div> </div> </div> </div> <div class="modal fade" id="addRelPanel" tabindex="-1" role="dialog" aria-labelledby="myModalLabel" aria-hidden="true"> <div class="modal-dialog"> <div class="modal-content" style="width:600px;"> <div class="modal-header"> <button type="button" class="close" data-dismiss="modal"><span aria-hidden="true">&times;</span><span class="sr-only">x</span></button> <h4 class="modal-title">添加企业或个人</h4> </div> <div class="modal-body" style="height: 445px"> <form class="form-horizontal" role="form"> <div class="form-group"> <div class="col-sm-12 m-t-md"> <input type="text" id="qrcomName" name="comName" class="form-control" value="" placeholder="请输入公司名称" autocomplete="off" oninput="qrsearchCom(event,this)"/> <section class="panel hidden-xs" id="qrsearchList" style="position: absolute;width: 560px;z-index: 10;display: none;"></section> </div> </div> </form> </div> </div> </div> </div> </div> <script type="text/javascript">
# 	 /*rightNav.js 使用变量*/
# 	 var personImg =  "/material/theme/chacha/cms/v2/images/leftnav/person.png";
# 	 var frimUrl = "";
# 	 var comDefaultImg = "/material/theme/chacha/cms/v2/images/company.jpg"
#
#     function jumpTax(){
#         window.location.href=encodeURI(INDEX_URL+"tax");
#     }
# </script> <script src="/material/theme/chacha/cms/v2/js/rightNav.js?timestamp=1497542400"></script> <style type="text/css">
#     #vipModal .modal-dialog{
#       width: 400px;
#       margin-top: 200px;
#     }
#     #vipModal .modal-content{
#
#       height: 350px;
#       border-radius: 0px;
#       text-align: center;
#     }
#     #vipModal img{
#       display: block;
#       margin: 0px auto;
#     }
#     #vipModal .close{
#       color: #128bed;
#       font-size: 40px;
#       opacity: 0.8;
#       font-weight: normal;
#       margin-right: 10px;
#       margin-top: 5px;
#     }
# </style> <div class="modal fade" id="vipModal" tabindex="-1" role="dialog" aria-labelledby="myModalLabel" aria-hidden="true"> <div class="modal-dialog nmodal"> <div class="modal-content"> <button type="button" class="close" data-dismiss="modal"><span aria-hidden="true">&times;</span><span class="sr-only">x</span></button> <div class="clearfix"></div> <img src="/material/theme/chacha/cms/v2/images/nno_image.png"> <span class="title">该功能 只对VIP开放哦</span> <div><a href="/vip" class="btn btn-primary m-t-md">立即开通</a></div> </div> </div> </div> <script type="text/javascript">
#     function showVipModal(title){
#         if(title){
#             $('#vipModal .title').text(title);
#         }else{
#             $('#vipModal .title').text('该功能 只对VIP开放哦');
#         }
#         $('#vipModal').modal('show');
#     }
# </script> <style type="text/css">
#     @keyframes popleft {0%   {margin-left: -100%;} 100% {margin-left: 0px;} }
#     @-moz-keyframes popleft {0%   {margin-left: -100%;} 100% {margin-left: 0px;} }
#     @-webkit-keyframes popleft {0%   {margin-left: -100%;} 100% {margin-left: 0px;} }
#
#     @keyframes popRight {0%   {margin-left: 0px;} 100% {margin-left: -100%;} }
#     @-moz-keyframes popRight {0%   {margin-left: 0px;} 100% {margin-left: -100%;} }
#     @-webkit-keyframes popRight {0%   {margin-left: 0px;} 100% {margin-left: -100%;} }
#
#
#     .bottomSuspend{
#         width: 100%;
#         position: fixed;
#         bottom: 0px;
#         z-index: 10;
#         background:url(/material/theme/chacha/cms/v2/images/app11.0.0.png) center bottom no-repeat;
#         height: 136px;
#     }
#
#     .bottomSuspend .attendDownload{
#         cursor: pointer;
#         width: 860px;
#         position: absolute;
#         bottom: 0px;
#         height: 90px;
#         left: 50%;
#         margin-left: -520px;
#     }
#
#
#     .acction-left{
#         z-index:10000;
#         margin-left: 0px !important; animation: popleft 0.5s; -moz-animation: popleft 0.5s; -webkit-animation: popleft 0.5s;
#     }
#     .acction-right{
#         margin-left: -100% !important; animation: popRight 0.5s; -moz-animation: popRight 0.5s; -webkit-animation: popRight 0.5s;
#     }
#
#     .bottomSuspend .closeSuspend{
#         position: absolute; top: 70px; right: 28px;
#         width: 40px;
#         height: 40px;
#         background: url(/material/theme/chacha/cms/v2/images/app10.0.2_close.png) no-repeat center center;
#         -webkit-transition: .5s;
#         transition: .5s;
#     }
#     .bottomSuspend .closeSuspend:hover{
#         transform: rotate(180deg);
#         -ms-transform: rotate(180deg);
#         -moz-transform: rotate(180deg);
#         -webkit-transform: rotate(180deg);
#         -o-transform: rotate(180deg);
#     }
#
#     .openSuspend{
#         z-index: 10;
#         position: fixed; bottom: 35px; left: 0px;
#         width: 56px;
#         height: 50px;
#         background: url(/material/theme/chacha/cms/v2/fapiao/app_down@2x.png) no-repeat center center;
#         background-size: 56px 50px;
#         display: none;
#     }
#
#     @media print {
#         a[href]:after {
#             content: none !important;
#         }
#         .bottomSuspend {
#             display: none;
#         }
#     }
#
# </style> <div id="openSuspend" class="openSuspend" style="cursor:pointer;"></div> <div class="bottomSuspend" id="bottomSuspend" style="margin-left: -100%;"> <div id="attendDownload" class="attendDownload"></div> <div id="closeSuspend" class="closeSuspend"></div> </div> <script type="text/javascript">
#     setTimeout(function() {
#         if(window.localStorage.getItem('bottomSuspendClose')=='1'){
#             $('#openSuspend').fadeIn();
#         }else{
#             $('#bottomSuspend').attr('class','bottomSuspend acction-left');
#         }
#     },1500);
#     $('#closeSuspend').click(function(e){
#         e.stopPropagation();
#         window.localStorage.setItem('bottomSuspendClose',1);
#         $('#bottomSuspend').attr('class','bottomSuspend acction-right');
#         setTimeout(function() {
#             $('#openSuspend').fadeIn();
#         },500);
#     });
#     $('#openSuspend').click(function(){
#         window.localStorage.setItem('bottomSuspendClose',0);
#         $('#openSuspend').fadeOut();
#         setTimeout(function() {
#             $('#bottomSuspend').attr('class','bottomSuspend acction-left');
#         },500);
#     });
#     $('#attendDownload').click(function(){
#         location.href = "http://www.qichacha.com/weixin_jump?from=web";
#     });
# </script> </body> </html>

# %%
select = etree.HTML(r.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-9a72090284ce> in <module>()
# ----> 1 select = etree.HTML(r.text)
#
# AttributeError: module 'xml.etree' has no attribute 'HTML'
